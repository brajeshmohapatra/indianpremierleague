# %%
import warnings
import numpy as np
import pandas as pd
from sqlalchemy import *
from IPython.display import display, HTML
from sqlalchemy.ext.declarative import declarative_base
warnings.filterwarnings('ignore')
pd.pandas.set_option('display.max_rows', None)
pd.pandas.set_option('display.max_columns', None)
display(HTML('<style>.container{width : 100% ! important;}</style>'))
# Out:
# <style>.container{width : 100% ! important;}</style>

# %%
url = 'mysql+mysqlconnector://{user}:{password}@{server}/{database}'.format(user = 'admin', password = 'adminroot', 
                                                                            server = 'indianpremierleague.cloqh08fxh1t.ap-south-1.rds.amazonaws.com',
                                                                            database = 'ipl')
engine = create_engine(url, echo = True)
base = declarative_base()

# %%
pd.read_sql_query('show tables;', engine.connect())
# Out:
# 2022-04-01 10:36:50,950 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'sql_mode'
# 2022-04-01 10:36:50,950 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-01 10:36:51,057 INFO sqlalchemy.engine.Engine SHOW VARIABLES LIKE 'lower_case_table_names'
# 2022-04-01 10:36:51,066 INFO sqlalchemy.engine.Engine [generated in 0.04868s] {}
# 2022-04-01 10:36:51,259 INFO sqlalchemy.engine.Engine SELECT DATABASE()
# 2022-04-01 10:36:51,259 INFO sqlalchemy.engine.Engine [raw sql] {}
# 2022-04-01 10:36:51,502 INFO sqlalchemy.engine.Engine show tables;
# 2022-04-01 10:36:51,502 INFO sqlalchemy.engine.Engine [raw sql] {}
# Empty DataFrame
# Columns: [Tables_in_ipl]
# Index: []

# %%
fixtures = pd.read_excel('Fixtures.xlsx')

# %%
fixtures.head()
# Out:
#    MATCH ID MATCH NO       DATE      TIME            HOME TEAM  \
# 0   1304047      1st 2022-03-26  07:30 PM  Chennai Super Kings
# 1   1304048      2nd 2022-03-27  03:30 PM       Delhi Capitals
# 2   1304049      3rd 2022-03-27  07:30 PM         Punjab Kings
# 3   1304050      4th 2022-03-28  07:30 PM       Gujarat Titans
# 4   1304051      5th 2022-03-29  07:30 PM  Sunrisers Hyderabad
#
#                      AWAY TEAM  \
# 0        Kolkata Knight Riders
# 1               Mumbai Indians
# 2  Royal Challengers Bangalore
# 3         Lucknow Super Giants
# 4             Rajasthan Royals
#
#                                                MATCH              VENUE  \
# 0  Chennai Super Kings vs Kolkata Knight Riders, ...   Wankhede Stadium
# 1         Delhi Capitals vs Mumbai Indians, 03:30 PM    Brabourne - CCI
# 2  Punjab Kings vs Royal Challengers Bangalore, 0...   DY Patil Stadium
# 3   Gujarat Titans vs Lucknow Super Giants, 07:30 PM   Wankhede Stadium
# 4  Sunrisers Hyderabad vs Rajasthan Royals, 07:30 PM  MCA Stadium, Pune
#
#                                                  URL
# 0  https://www.espncricinfo.com/series/indian-pre...
# 1  https://www.espncricinfo.com/series/indian-pre...
# 2  https://www.espncricinfo.com/series/indian-pre...
# 3  https://www.espncricinfo.com/series/indian-pre...
# 4  https://www.espncricinfo.com/series/indian-pre...

# %%
fixtures.to_sql(name = 'fixtures', con = engine, if_exists = 'append', chunksize = 1500, index = None)
# Out:
# 2022-04-01 10:38:37,949 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-04-01 10:38:37,949 INFO sqlalchemy.engine.Engine [generated in 0.04903s] {'table_schema': 'ipl', 'table_name': 'fixtures'}
# 2022-04-01 10:38:38,048 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-01 10:38:38,111 INFO sqlalchemy.engine.Engine
# CREATE TABLE fixtures (
# 	`MATCH ID` BIGINT,
# 	`MATCH NO` TEXT,
# 	`DATE` DATETIME,
# 	`TIME` TEXT,
# 	`HOME TEAM` TEXT,
# 	`AWAY TEAM` TEXT,
# 	`MATCH` TEXT,
# 	`VENUE` TEXT,
# 	`URL` TEXT
# )
#
#
# 2022-04-01 10:38:38,111 INFO sqlalchemy.engine.Engine [no key 0.04872s] {}
# 2022-04-01 10:38:38,221 INFO sqlalchemy.engine.Engine COMMIT
# 2022-04-01 10:38:38,315 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-01 10:38:38,370 INFO sqlalchemy.engine.Engine INSERT INTO fixtures (`MATCH ID`, `MATCH NO`, `DATE`, `TIME`, `HOME TEAM`, `AWAY TEAM`, `MATCH`, `VENUE`, `URL`) VALUES (%(MATCH ID)s, %(MATCH NO)s, %(DATE)s, %(TIME)s, %(HOME TEAM)s, %(AWAY TEAM)s, %(MATCH)s, %(VENUE)s, %(URL)s)
# 2022-04-01 10:38:38,370 INFO sqlalchemy.engine.Engine [generated in 0.04904s] ({'MATCH ID': 1304047, 'MATCH NO': '1st', 'DATE': datetime.datetime(2022, 3, 26, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Chennai Super Kings', 'AWAY TEAM': 'Kolkata Knight Riders', 'MATCH': 'Chennai Super Kings vs Kolkata Knight Riders, 07:30 PM', 'VENUE': 'Wankhede Stadium', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/chennai-super-kings-vs-kolkata-knight-riders-1st-match-1304047/live-cricket-score'}, {'MATCH ID': 1304048, 'MATCH NO': '2nd', 'DATE': datetime.datetime(2022, 3, 27, 0, 0), 'TIME': '03:30 PM', 'HOME TEAM': 'Delhi Capitals', 'AWAY TEAM': 'Mumbai Indians', 'MATCH': 'Delhi Capitals vs Mumbai Indians, 03:30 PM', 'VENUE': 'Brabourne - CCI', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/delhi-capitals-vs-mumbai-indians-2nd-match-1304048/live-cricket-score'}, {'MATCH ID': 1304049, 'MATCH NO': '3rd', 'DATE': datetime.datetime(2022, 3, 27, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Punjab Kings', 'AWAY TEAM': 'Royal Challengers Bangalore', 'MATCH': 'Punjab Kings vs Royal Challengers Bangalore, 07:30 PM', 'VENUE': 'DY Patil Stadium', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/punjab-kings-vs-royal-challengers-bangalore-3rd-match-1304049/live-cricket-score'}, {'MATCH ID': 1304050, 'MATCH NO': '4th', 'DATE': datetime.datetime(2022, 3, 28, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Gujarat Titans', 'AWAY TEAM': 'Lucknow Super Giants', 'MATCH': 'Gujarat Titans vs Lucknow Super Giants, 07:30 PM', 'VENUE': 'Wankhede Stadium', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/gujarat-titans-vs-lucknow-super-giants-4th-match-1304050/live-cricket-score'}, {'MATCH ID': 1304051, 'MATCH NO': '5th', 'DATE': datetime.datetime(2022, 3, 29, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Sunrisers Hyderabad', 'AWAY TEAM': 'Rajasthan Royals', 'MATCH': 'Sunrisers Hyderabad vs Rajasthan Royals, 07:30 PM', 'VENUE': 'MCA Stadium, Pune', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/sunrisers-hyderabad-vs-rajasthan-royals-5th-match-1304051/live-cricket-score'}, {'MATCH ID': 1304052, 'MATCH NO': '6th', 'DATE': datetime.datetime(2022, 3, 30, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Royal Challengers Bangalore', 'AWAY TEAM': 'Kolkata Knight Riders', 'MATCH': 'Royal Challengers Bangalore vs Kolkata Knight Riders, 07:30 PM', 'VENUE': 'DY Patil Stadium', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/royal-challengers-bangalore-vs-kolkata-knight-riders-6th-match-1304052/live-cricket-score'}, {'MATCH ID': 1304053, 'MATCH NO': '7th', 'DATE': datetime.datetime(2022, 3, 31, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Lucknow Super Giants', 'AWAY TEAM': 'Chennai Super Kings', 'MATCH': 'Lucknow Super Giants vs Chennai Super Kings, 07:30 PM', 'VENUE': 'Brabourne - CCI', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/lucknow-super-giants-vs-chennai-super-kings-7th-match-1304053/live-cricket-score'}, {'MATCH ID': 1304054, 'MATCH NO': '8th', 'DATE': datetime.datetime(2022, 4, 1, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Kolkata Knight Riders', 'AWAY TEAM': 'Punjab Kings', 'MATCH': 'Kolkata Knight Riders vs Punjab Kings, 07:30 PM', 'VENUE': 'Wankhede Stadium', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/kolkata-knight-riders-vs-punjab-kings-8th-match-1304054/live-cricket-score'}  ... displaying 10 of 70 total bound parameter sets ...  {'MATCH ID': 1304115, 'MATCH NO': '69th', 'DATE': datetime.datetime(2022, 5, 21, 0, 0), 'TIME': '07:30 PM', 'HOME TEAM': 'Mumbai Indians', 'AWAY TEAM': 'Delhi Capitals', 'MATCH': 'Mumbai Indians vs Delhi Capitals, 07:30 PM', 'VENUE': 'Wankhede Stadium', 'URL': 'https://www.espncricinfo.com/series/indian-premier-league-2022-1298423/mumbai-indians-vs-delhi-capitals-69th-match-1304115/live-cricket-score'}, {'MA ...
# 2022-04-01 10:38:38,474 INFO sqlalchemy.engine.Engine COMMIT

# %%
match_list = pd.read_csv('Match Processed.csv')
match_details = pd.read_csv('IPL.csv')

# %%
match_list.to_sql(name = 'match_list', con = engine, if_exists = 'append', chunksize = 1500, index = None)
# Out:
# 2022-04-01 10:38:48,405 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-04-01 10:38:48,421 INFO sqlalchemy.engine.Engine [cached since 10.51s ago] {'table_schema': 'ipl', 'table_name': 'match_list'}
# 2022-04-01 10:38:48,521 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-01 10:38:48,568 INFO sqlalchemy.engine.Engine
# CREATE TABLE match_list (
# 	match_id BIGINT,
# 	year BIGINT,
# 	city TEXT,
# 	date TEXT,
# 	player_of_match TEXT,
# 	venue TEXT,
# 	team1 TEXT,
# 	team2 TEXT,
# 	toss_winner TEXT,
# 	toss_decision TEXT,
# 	winner TEXT,
# 	result TEXT,
# 	result_margin FLOAT(53),
# 	method TEXT,
# 	players TEXT,
# 	umpire1 TEXT,
# 	umpire2 TEXT,
# 	playoff BIGINT,
# 	knockout BIGINT,
# 	final BIGINT,
# 	innings_1_score FLOAT(53),
# 	innings_1_wickets FLOAT(53),
# 	innings_2_score FLOAT(53),
# 	innings_2_wickets FLOAT(53),
# 	innings_1_bat_team TEXT,
# 	innings_2_bat_team TEXT
# )
#
#
# 2022-04-01 10:38:48,568 INFO sqlalchemy.engine.Engine [no key 0.04874s] {}
# 2022-04-01 10:38:48,643 INFO sqlalchemy.engine.Engine COMMIT
# 2022-04-01 10:38:48,743 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-01 10:38:48,814 INFO sqlalchemy.engine.Engine INSERT INTO match_list (match_id, year, city, date, player_of_match, venue, team1, team2, toss_winner, toss_decision, winner, result, result_margin, method, players, umpire1, umpire2, playoff, knockout, final, innings_1_score, innings_1_wickets, innings_2_score, innings_2_wickets, innings_1_bat_team, innings_2_bat_team) VALUES (%(match_id)s, %(year)s, %(city)s, %(date)s, %(player_of_match)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(winner)s, %(result)s, %(result_margin)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(playoff)s, %(knockout)s, %(final)s, %(innings_1_score)s, %(innings_1_wickets)s, %(innings_2_score)s, %(innings_2_wickets)s, %(innings_1_bat_team)s, %(innings_2_bat_team)s)
# 2022-04-01 10:38:48,814 INFO sqlalchemy.engine.Engine [generated in 0.06614s] ({'match_id': 335982, 'year': 2008, 'city': 'Bangalore', 'date': '18-04-2008', 'player_of_match': 'BB McCullum', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shukla, WP Saha, AB Agarkar, AB Dinda, M Kartik, I Sharma', 'umpire1': 'Asad Rauf', 'umpire2': 'RE Koertzen', 'playoff': 0, 'knockout': 0, 'final': 0, 'innings_1_score': 222.0, 'innings_1_wickets': 3.0, 'innings_2_score': 82.0, 'innings_2_wickets': 10.0, 'innings_1_bat_team': 'Kolkata Knight Riders', 'innings_2_bat_team': 'Royal Challengers Bangalore'}, {'match_id': 335983, 'year': 2008, 'city': 'Chandigarh', 'date': '19-04-2008', 'player_of_match': 'MEK Hussey', 'venue': 'Punjab Cricket Association Stadium, Mohali', 'team1': 'Kings XI Punjab', 'team2': 'Chennai Super Kings', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 33.0, 'method': None, 'players': 'K Goel, JR Hopes, KC Sangakkara, Yuvraj Singh, SM Katich, IK Pathan, P Dharmani, B Lee, PP Chawla, WA Mota, S Sreesanth, PA Patel, ML Hayden, MEK Hussey, MS Dhoni, SK Raina, JDP Oram, S Badrinath, Joginder Sharma, P Amarnath, MS Gony, M Muralitharan', 'umpire1': 'MR Benson', 'umpire2': 'SL Shastri', 'playoff': 0, 'knockout': 0, 'final': 0, 'innings_1_score': 240.0, 'innings_1_wickets': 5.0, 'innings_2_score': 207.0, 'innings_2_wickets': 4.0, 'innings_1_bat_team': 'Chennai Super Kings', 'innings_2_bat_team': 'Kings XI Punjab'}, {'match_id': 335984, 'year': 2008, 'city': 'Delhi', 'date': '19-04-2008', 'player_of_match': 'MF Maharoof', 'venue': 'Feroz Shah Kotla', 'team1': 'Delhi Daredevils', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'winner': 'Delhi Daredevils', 'result': 'wickets', 'result_margin': 9.0, 'method': None, 'players': 'G Gambhir, V Sehwag, S Dhawan, MK Tiwary, KD Karthik, R Bhatia, M Manhas, DL Vettori, MF Maharoof, B Geeves, GD McGrath, T Kohli, YK Pathan, SR Watson, M Kaif, DS Lehmann, RA Jadeja, M Rawat, D Salunkhe, SK Warne, SK Trivedi, MM Patel', 'umpire1': 'Aleem Dar', 'umpire2': 'GA Pratapkumar', 'playoff': 0, 'knockout': 0, 'final': 0, 'innings_1_score': 129.0, 'innings_1_wickets': 8.0, 'innings_2_score': 132.0, 'innings_2_wickets': 1.0, 'innings_1_bat_team': 'Rajasthan Royals', 'innings_2_bat_team': 'Delhi Daredevils'}, {'match_id': 335985, 'year': 2008, 'city': 'Mumbai', 'date': '20-04-2008', 'player_of_match': 'MV Boucher', 'venue': 'Wankhede Stadium', 'team1': 'Mumbai Indians', 'team2': 'Royal Challengers Bangalore', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'bat', 'winner': 'Royal Challengers Bangalore', 'result': 'wickets', 'result_margin': 5.0, 'method': None, 'players': 'L Ronchi, ST Jayasuriya, DJ Thornely, RV Uthappa, PR Shah, AM Nayar, SM Pollock, Harbhajan Singh, MA Khote, A Nehra, DS Kulkarni, S Chanderpaul, R Dravid, LRPL Taylor, JH Kallis, V Kohli, MV Boucher, B Akhil, P Kumar, Z Khan, SB Joshi, R Vinay Kumar', 'umpire1': 'SJ Davis', 'umpire2': 'DJ Harper', 'playoff': 0, 'knockout': 0, 'final': 0, 'innings_1_score': 165.0, 'innings_1_wickets': 7.0, 'innings_2_score': 166.0, 'innings_2_wickets': 5.0, 'innings_1_bat_team': 'Mumbai Indians', 'innings_2_bat_team': 'Royal Challengers Bangalore'}, {'match_id': 335986, 'year': 2008, 'city': 'Kolkata', 'date': '20-04-2008', 'player_of_match': 'DJ Hussey', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Deccan Chargers', 'toss_winner': 'Deccan Chargers', 'toss_decision': 'bat', 'winner': 'Kolkata Knight Ri ...
# 2022-04-01 10:38:49,260 INFO sqlalchemy.engine.Engine COMMIT

# %%
match_details.to_sql(name = 'match_details', con = engine, if_exists = 'append', chunksize = 5000, index = None)
# Out:
# 2022-04-01 10:38:53,470 INFO sqlalchemy.engine.Engine SELECT COUNT(*) FROM information_schema.tables WHERE table_schema = %(table_schema)s AND table_name = %(table_name)s
# 2022-04-01 10:38:53,470 INFO sqlalchemy.engine.Engine [cached since 15.56s ago] {'table_schema': 'ipl', 'table_name': 'match_details'}
# 2022-04-01 10:38:53,562 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-01 10:38:53,609 INFO sqlalchemy.engine.Engine
# CREATE TABLE match_details (
# 	match_id BIGINT,
# 	year BIGINT,
# 	date TEXT,
# 	city TEXT,
# 	venue TEXT,
# 	team1 TEXT,
# 	team2 TEXT,
# 	toss_winner TEXT,
# 	toss_decision TEXT,
# 	innings BIGINT,
# 	batting_team TEXT,
# 	bowling_team TEXT,
# 	batsman TEXT,
# 	non_striker TEXT,
# 	bowler TEXT,
# 	overs BIGINT,
# 	balls BIGINT,
# 	batsman_runs FLOAT(53),
# 	extra_runs FLOAT(53),
# 	total_runs FLOAT(53),
# 	non_boundary BIGINT,
# 	is_wicket BIGINT,
# 	dismissal_kind TEXT,
# 	player_dismissed TEXT,
# 	fielder TEXT,
# 	extras_type TEXT,
# 	runs BIGINT,
# 	wickets BIGINT,
# 	runs_last_5_overs BIGINT,
# 	wickets_last_5_overs BIGINT,
# 	target_overs FLOAT(53),
# 	target_runs FLOAT(53),
# 	balls_remaining BIGINT,
# 	runs_scored_in_remaining_balls BIGINT,
# 	runs_required BIGINT,
# 	winner TEXT,
# 	result TEXT,
# 	result_margin FLOAT(53),
# 	player_of_match TEXT,
# 	playoff BIGINT,
# 	knockout BIGINT,
# 	final BIGINT,
# 	method TEXT,
# 	players TEXT,
# 	umpire1 TEXT,
# 	umpire2 TEXT,
# 	final_score FLOAT(53),
# 	total_wickets BIGINT
# )
#
#
# 2022-04-01 10:38:53,625 INFO sqlalchemy.engine.Engine [no key 0.04971s] {}
# 2022-04-01 10:38:53,709 INFO sqlalchemy.engine.Engine COMMIT
# 2022-04-01 10:38:54,216 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2022-04-01 10:38:54,491 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:38:54,491 INFO sqlalchemy.engine.Engine [generated in 0.23464s] ({'match_id': 335982, 'year': 2008, 'date': '2008-04-18', 'city': 'Bangalore', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Royal Challengers Bangalore', 'batsman': 'SC Ganguly', 'non_striker': 'BB McCullum', 'bowler': 'P Kumar', 'overs': 0, 'balls': 1, 'batsman_runs': 0.0, 'extra_runs': 1.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'legbyes', 'runs': 1, 'wickets': 0, 'runs_last_5_overs': 1, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 119, 'runs_scored_in_remaining_balls': 221, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'player_of_match': 'BB McCullum', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shukla, WP Saha, AB Agarkar, AB Dinda, M Kartik, I Sharma', 'umpire1': 'Asad Rauf', 'umpire2': 'RE Koertzen', 'final_score': 222.0, 'total_wickets': 3}, {'match_id': 335982, 'year': 2008, 'date': '2008-04-18', 'city': 'Bangalore', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Royal Challengers Bangalore', 'batsman': 'BB McCullum', 'non_striker': 'SC Ganguly', 'bowler': 'P Kumar', 'overs': 0, 'balls': 2, 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 1, 'wickets': 0, 'runs_last_5_overs': 1, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 118, 'runs_scored_in_remaining_balls': 221, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'player_of_match': 'BB McCullum', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shukla, WP Saha, AB Agarkar, AB Dinda, M Kartik, I Sharma', 'umpire1': 'Asad Rauf', 'umpire2': 'RE Koertzen', 'final_score': 222.0, 'total_wickets': 3}, {'match_id': 335982, 'year': 2008, 'date': '2008-04-18', 'city': 'Bangalore', 'venue': 'M Chinnaswamy Stadium', 'team1': 'Royal Challengers Bangalore', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Royal Challengers Bangalore', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Royal Challengers Bangalore', 'batsman': 'BB McCullum', 'non_striker': 'SC Ganguly', 'bowler': 'P Kumar', 'overs': 0, 'balls': 3, 'batsman_runs': 0.0, 'extra_runs': 1.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'wides', 'runs': 2, 'wickets': 0, 'runs_last_5_overs': 2, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 117, 'runs_scored_in_remaining_balls': 220, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 140.0, 'player_of_match': 'BB McCullum', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'R Dravid, W Jaffer, V Kohli, JH Kallis, CL White, MV Boucher, B Akhil, AA Noffke, P Kumar, Z Khan, SB Joshi, SC Ganguly, BB McCullum, RT Ponting, DJ Hussey, Mohammad Hafeez, LR Shuk ...
# 2022-04-01 10:38:56,145 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:38:56,145 INFO sqlalchemy.engine.Engine [cached since 1.889s ago] ({'match_id': 336003, 'year': 2008, 'date': '2008-03-05', 'city': 'Chandigarh', 'venue': 'Punjab Cricket Association IS Bindra Stadium', 'team1': 'Punjab Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Punjab Kings', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'SE Marsh', 'non_striker': 'JR Hopes', 'bowler': 'AB Agarkar', 'overs': 1, 'balls': 1, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 6, 'wickets': 0, 'runs_last_5_overs': 6, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 113, 'runs_scored_in_remaining_balls': 172, 'runs_required': 0, 'winner': 'Kings XI Punjab', 'result': 'runs', 'result_margin': 9.0, 'player_of_match': 'IK Pathan', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'SE Marsh, JR Hopes, KC Sangakkara, Yuvraj Singh, DPMD Jayawardene, K Goel, IK Pathan, PP Chawla, S Sreesanth, VRV Singh, Gagandeep Singh, Mohammad Hafeez, SC Ganguly, DB Das, BJ Hodge, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, Umar Gul, I Sharma, AB Dinda', 'umpire1': 'DJ Harper', 'umpire2': 'I Shivram', 'final_score': 178.0, 'total_wickets': 6}, {'match_id': 336003, 'year': 2008, 'date': '2008-03-05', 'city': 'Chandigarh', 'venue': 'Punjab Cricket Association IS Bindra Stadium', 'team1': 'Punjab Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Punjab Kings', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'JR Hopes', 'non_striker': 'SE Marsh', 'bowler': 'AB Agarkar', 'overs': 1, 'balls': 2, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 10, 'wickets': 0, 'runs_last_5_overs': 10, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 112, 'runs_scored_in_remaining_balls': 168, 'runs_required': 0, 'winner': 'Kings XI Punjab', 'result': 'runs', 'result_margin': 9.0, 'player_of_match': 'IK Pathan', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'SE Marsh, JR Hopes, KC Sangakkara, Yuvraj Singh, DPMD Jayawardene, K Goel, IK Pathan, PP Chawla, S Sreesanth, VRV Singh, Gagandeep Singh, Mohammad Hafeez, SC Ganguly, DB Das, BJ Hodge, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, Umar Gul, I Sharma, AB Dinda', 'umpire1': 'DJ Harper', 'umpire2': 'I Shivram', 'final_score': 178.0, 'total_wickets': 6}, {'match_id': 336003, 'year': 2008, 'date': '2008-03-05', 'city': 'Chandigarh', 'venue': 'Punjab Cricket Association IS Bindra Stadium', 'team1': 'Punjab Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Punjab Kings', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'JR Hopes', 'non_striker': 'SE Marsh', 'bowler': 'AB Agarkar', 'overs': 1, 'balls': 3, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 14, 'wickets': 0, 'runs_last_5_overs': 14, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 111, 'runs_scored_in_remaining_balls': 164, 'runs_required': 0, 'winner': 'Kings XI Punjab', 'result': 'runs', 'result_margin': 9.0, 'player_of_match': 'IK Pathan', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'SE Marsh, JR Hopes, KC Sangakkara, Yuvraj Singh, DPMD Jayawardene, K Goel, IK Pathan, PP Chawla, S Sreesanth, VRV Singh, Gagandeep Singh, Mohammad Hafeez, SC Ganguly, DB Das, BJ Hodge, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, Umar Gul, I ...
# 2022-04-01 10:38:57,748 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:38:57,748 INFO sqlalchemy.engine.Engine [cached since 3.495s ago] ({'match_id': 336025, 'year': 2008, 'date': '2008-05-18', 'city': 'Kolkata', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Chennai Super Kings', 'toss_winner': 'Kolkata Knight Riders', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Chennai Super Kings', 'batsman': 'Salman Butt', 'non_striker': 'DB Das', 'bowler': 'L Balaji', 'overs': 10, 'balls': 2, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 66, 'wickets': 2, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 58, 'runs_scored_in_remaining_balls': 83, 'runs_required': 0, 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 3.0, 'player_of_match': 'M Ntini', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': 'D/L', 'players': 'Salman Butt, Mohammad Hafeez, SC Ganguly, DB Das, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, I Sharma, AB Dinda, Shoaib Akhtar, PA Patel, SP Fleming, S Vidyut, SK Raina, S Badrinath, MS Dhoni, JA Morkel, MS Gony, L Balaji, M Muralitharan, M Ntini', 'umpire1': 'Asad Rauf', 'umpire2': 'K Hariharan', 'final_score': 149.0, 'total_wickets': 5}, {'match_id': 336025, 'year': 2008, 'date': '2008-05-18', 'city': 'Kolkata', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Chennai Super Kings', 'toss_winner': 'Kolkata Knight Riders', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Chennai Super Kings', 'batsman': 'Salman Butt', 'non_striker': 'DB Das', 'bowler': 'L Balaji', 'overs': 10, 'balls': 3, 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 66, 'wickets': 2, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 57, 'runs_scored_in_remaining_balls': 83, 'runs_required': 0, 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 3.0, 'player_of_match': 'M Ntini', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': 'D/L', 'players': 'Salman Butt, Mohammad Hafeez, SC Ganguly, DB Das, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, I Sharma, AB Dinda, Shoaib Akhtar, PA Patel, SP Fleming, S Vidyut, SK Raina, S Badrinath, MS Dhoni, JA Morkel, MS Gony, L Balaji, M Muralitharan, M Ntini', 'umpire1': 'Asad Rauf', 'umpire2': 'K Hariharan', 'final_score': 149.0, 'total_wickets': 5}, {'match_id': 336025, 'year': 2008, 'date': '2008-05-18', 'city': 'Kolkata', 'venue': 'Eden Gardens', 'team1': 'Kolkata Knight Riders', 'team2': 'Chennai Super Kings', 'toss_winner': 'Kolkata Knight Riders', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Chennai Super Kings', 'batsman': 'Salman Butt', 'non_striker': 'DB Das', 'bowler': 'L Balaji', 'overs': 10, 'balls': 4, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 67, 'wickets': 2, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 56, 'runs_scored_in_remaining_balls': 82, 'runs_required': 0, 'winner': 'Chennai Super Kings', 'result': 'runs', 'result_margin': 3.0, 'player_of_match': 'M Ntini', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': 'D/L', 'players': 'Salman Butt, Mohammad Hafeez, SC Ganguly, DB Das, DJ Hussey, LR Shukla, WP Saha, AB Agarkar, I Sharma, AB Dinda, Shoaib Akhtar, PA Patel, SP Fleming, S Vidyut, SK Raina, S Badrinath, MS Dhoni, JA Morkel, MS Gony, L Balaji, M Muralitharan, M Ntini', 'umpire1': 'Asad Rauf', 'umpire2': 'K Harihara ...
# 2022-04-01 10:38:59,277 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:38:59,277 INFO sqlalchemy.engine.Engine [cached since 5.023s ago] ({'match_id': 392189, 'year': 2009, 'date': '2009-04-23', 'city': 'Durban', 'venue': 'Kingsmead', 'team1': 'Chennai Super Kings', 'team2': 'Delhi Capitals', 'toss_winner': 'Delhi Daredevils', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Delhi Capitals', 'bowling_team': 'Chennai Super Kings', 'batsman': 'AB de Villiers', 'non_striker': 'MK Tiwary', 'bowler': 'A Flintoff', 'overs': 14, 'balls': 1, 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 116, 'wickets': 4, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 1, 'target_overs': None, 'target_runs': None, 'balls_remaining': 35, 'runs_scored_in_remaining_balls': 73, 'runs_required': 0, 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 9.0, 'player_of_match': 'AB de Villiers', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PA Patel, ML Hayden, SK Raina, MS Dhoni, A Flintoff, JA Morkel, S Badrinath, MS Gony, Joginder Sharma, L Balaji, M Muralitharan, G Gambhir, V Sehwag, AB de Villiers, TM Dilshan, KD Karthik, MK Tiwary, DL Vettori, DP Nannes, AM Salvi, PJ Sangwan, A Nehra', 'umpire1': 'BR Doctrove', 'umpire2': 'SJA Taufel', 'final_score': 189.0, 'total_wickets': 5}, {'match_id': 392189, 'year': 2009, 'date': '2009-04-23', 'city': 'Durban', 'venue': 'Kingsmead', 'team1': 'Chennai Super Kings', 'team2': 'Delhi Capitals', 'toss_winner': 'Delhi Daredevils', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Delhi Capitals', 'bowling_team': 'Chennai Super Kings', 'batsman': 'AB de Villiers', 'non_striker': 'MK Tiwary', 'bowler': 'A Flintoff', 'overs': 14, 'balls': 2, 'batsman_runs': 6.0, 'extra_runs': 0.0, 'total_runs': 6.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 122, 'wickets': 4, 'runs_last_5_overs': 35, 'wickets_last_5_overs': 1, 'target_overs': None, 'target_runs': None, 'balls_remaining': 34, 'runs_scored_in_remaining_balls': 67, 'runs_required': 0, 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 9.0, 'player_of_match': 'AB de Villiers', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PA Patel, ML Hayden, SK Raina, MS Dhoni, A Flintoff, JA Morkel, S Badrinath, MS Gony, Joginder Sharma, L Balaji, M Muralitharan, G Gambhir, V Sehwag, AB de Villiers, TM Dilshan, KD Karthik, MK Tiwary, DL Vettori, DP Nannes, AM Salvi, PJ Sangwan, A Nehra', 'umpire1': 'BR Doctrove', 'umpire2': 'SJA Taufel', 'final_score': 189.0, 'total_wickets': 5}, {'match_id': 392189, 'year': 2009, 'date': '2009-04-23', 'city': 'Durban', 'venue': 'Kingsmead', 'team1': 'Chennai Super Kings', 'team2': 'Delhi Capitals', 'toss_winner': 'Delhi Daredevils', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Delhi Capitals', 'bowling_team': 'Chennai Super Kings', 'batsman': 'AB de Villiers', 'non_striker': 'MK Tiwary', 'bowler': 'A Flintoff', 'overs': 14, 'balls': 3, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 123, 'wickets': 4, 'runs_last_5_overs': 35, 'wickets_last_5_overs': 1, 'target_overs': None, 'target_runs': None, 'balls_remaining': 33, 'runs_scored_in_remaining_balls': 66, 'runs_required': 0, 'winner': 'Delhi Daredevils', 'result': 'runs', 'result_margin': 9.0, 'player_of_match': 'AB de Villiers', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PA Patel, ML Hayden, SK Raina, MS Dhoni, A Flintoff, JA Morkel, S Badrinath, MS Gony, Joginder Sharma, L Balaji, M Muralitharan, G Gambhir, V Sehwag, AB de Villiers, TM Dilshan, KD Karthik, MK Tiwary, DL Vettori, DP Nannes, AM Salvi, PJ Sangwan, A Nehra', 'umpire1': 'BR Doctrove', 'umpire2': 'SJA Taufel', 'fina ...
# 2022-04-01 10:39:00,979 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:39:00,979 INFO sqlalchemy.engine.Engine [cached since 6.727s ago] ({'match_id': 392210, 'year': 2009, 'date': '2009-05-05', 'city': 'Durban', 'venue': 'Kingsmead', 'team1': 'Punjab Kings', 'team2': 'Rajasthan Royals', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'field', 'innings': 2, 'batting_team': 'Punjab Kings', 'bowling_team': 'Rajasthan Royals', 'batsman': 'IK Pathan', 'non_striker': 'Yuvraj Singh', 'bowler': 'YK Pathan', 'overs': 12, 'balls': 1, 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 76, 'wickets': 5, 'runs_last_5_overs': 32, 'wickets_last_5_overs': 0, 'target_overs': 20.0, 'target_runs': 212.0, 'balls_remaining': 47, 'runs_scored_in_remaining_balls': 0, 'runs_required': 136, 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 78.0, 'player_of_match': 'GC Smith', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'S Sohal, KC Sangakkara, K Goel, SM Katich, DPMD Jayawardene, Yuvraj Singh, IK Pathan, PP Chawla, RR Powar, S Sreesanth, YA Abdulla, NV Ojha, GC Smith, YK Pathan, RA Jadeja, LA Carseldine, AS Raut, NK Patel, SK Warne, SM Harwood, SK Trivedi, A Singh', 'umpire1': 'SS Hazare', 'umpire2': 'IL Howell', 'final_score': 133.0, 'total_wickets': 8}, {'match_id': 392210, 'year': 2009, 'date': '2009-05-05', 'city': 'Durban', 'venue': 'Kingsmead', 'team1': 'Punjab Kings', 'team2': 'Rajasthan Royals', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'field', 'innings': 2, 'batting_team': 'Punjab Kings', 'bowling_team': 'Rajasthan Royals', 'batsman': 'IK Pathan', 'non_striker': 'Yuvraj Singh', 'bowler': 'YK Pathan', 'overs': 12, 'balls': 2, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 77, 'wickets': 5, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'target_overs': 20.0, 'target_runs': 212.0, 'balls_remaining': 46, 'runs_scored_in_remaining_balls': 0, 'runs_required': 135, 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 78.0, 'player_of_match': 'GC Smith', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'S Sohal, KC Sangakkara, K Goel, SM Katich, DPMD Jayawardene, Yuvraj Singh, IK Pathan, PP Chawla, RR Powar, S Sreesanth, YA Abdulla, NV Ojha, GC Smith, YK Pathan, RA Jadeja, LA Carseldine, AS Raut, NK Patel, SK Warne, SM Harwood, SK Trivedi, A Singh', 'umpire1': 'SS Hazare', 'umpire2': 'IL Howell', 'final_score': 133.0, 'total_wickets': 8}, {'match_id': 392210, 'year': 2009, 'date': '2009-05-05', 'city': 'Durban', 'venue': 'Kingsmead', 'team1': 'Punjab Kings', 'team2': 'Rajasthan Royals', 'toss_winner': 'Kings XI Punjab', 'toss_decision': 'field', 'innings': 2, 'batting_team': 'Punjab Kings', 'bowling_team': 'Rajasthan Royals', 'batsman': 'Yuvraj Singh', 'non_striker': 'IK Pathan', 'bowler': 'YK Pathan', 'overs': 12, 'balls': 3, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 81, 'wickets': 5, 'runs_last_5_overs': 36, 'wickets_last_5_overs': 0, 'target_overs': 20.0, 'target_runs': 212.0, 'balls_remaining': 45, 'runs_scored_in_remaining_balls': 0, 'runs_required': 131, 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 78.0, 'player_of_match': 'GC Smith', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'S Sohal, KC Sangakkara, K Goel, SM Katich, DPMD Jayawardene, Yuvraj Singh, IK Pathan, PP Chawla, RR Powar, S Sreesanth, YA Abdulla, NV Ojha, GC Smith, YK Pathan, RA Jadeja, LA Carseldine, AS Raut, NK Patel, SK Warne, SM Harwood, SK Trivedi, A Singh', 'umpire1': 'SS Hazare', 'umpire2': 'IL Howell', 'final_score': 133.0, 'total_wickets': 8}, {'match_id': 392210, 'year': 2009, ...
# 2022-04-01 10:39:03,271 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:39:03,271 INFO sqlalchemy.engine.Engine [cached since 9.013s ago] ({'match_id': 392231, 'year': 2009, 'date': '2009-05-18', 'city': 'Centurion', 'venue': 'SuperSport Park', 'team1': 'Chennai Super Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Chennai Super Kings', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'SK Raina', 'non_striker': 'MS Dhoni', 'bowler': 'AB Dinda', 'overs': 16, 'balls': 1, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 141, 'wickets': 2, 'runs_last_5_overs': 46, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 23, 'runs_scored_in_remaining_balls': 47, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 7.0, 'player_of_match': 'BJ Hodge', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PA Patel, GJ Bailey, SK Raina, MS Dhoni, JA Morkel, S Badrinath, JDP Oram, SB Jakati, L Balaji, M Muralitharan, S Tyagi, BB McCullum, SC Ganguly, BJ Hodge, DJ Hussey, WP Saha, LR Shukla, AB Agarkar, Anureet Singh, M Kartik, AB Dinda, BAW Mendis', 'umpire1': 'SJA Taufel', 'umpire2': 'RB Tiffin', 'final_score': 188.0, 'total_wickets': 3}, {'match_id': 392231, 'year': 2009, 'date': '2009-05-18', 'city': 'Centurion', 'venue': 'SuperSport Park', 'team1': 'Chennai Super Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Chennai Super Kings', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'MS Dhoni', 'non_striker': 'SK Raina', 'bowler': 'AB Dinda', 'overs': 16, 'balls': 2, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 145, 'wickets': 2, 'runs_last_5_overs': 49, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 22, 'runs_scored_in_remaining_balls': 43, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 7.0, 'player_of_match': 'BJ Hodge', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PA Patel, GJ Bailey, SK Raina, MS Dhoni, JA Morkel, S Badrinath, JDP Oram, SB Jakati, L Balaji, M Muralitharan, S Tyagi, BB McCullum, SC Ganguly, BJ Hodge, DJ Hussey, WP Saha, LR Shukla, AB Agarkar, Anureet Singh, M Kartik, AB Dinda, BAW Mendis', 'umpire1': 'SJA Taufel', 'umpire2': 'RB Tiffin', 'final_score': 188.0, 'total_wickets': 3}, {'match_id': 392231, 'year': 2009, 'date': '2009-05-18', 'city': 'Centurion', 'venue': 'SuperSport Park', 'team1': 'Chennai Super Kings', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Chennai Super Kings', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Chennai Super Kings', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'MS Dhoni', 'non_striker': 'SK Raina', 'bowler': 'AB Dinda', 'overs': 16, 'balls': 3, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 146, 'wickets': 2, 'runs_last_5_overs': 49, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 21, 'runs_scored_in_remaining_balls': 42, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'wickets', 'result_margin': 7.0, 'player_of_match': 'BJ Hodge', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PA Patel, GJ Bailey, SK Raina, MS Dhoni, JA Morkel, S Badrinath, JDP Oram, SB Jakati, L Balaji, M Muralitharan, S Tyagi, BB McCullum, SC Ganguly, BJ Hodge, DJ Hussey, WP Saha, LR Shukla, AB Agarkar, Anureet Singh, M Kartik, AB Dinda, BAW Mendis', 'umpire1': 'SJA Taufel', 'umpi ...
# 2022-04-01 10:39:05,690 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:39:05,698 INFO sqlalchemy.engine.Engine [cached since 11.44s ago] ({'match_id': 419118, 'year': 2010, 'date': '2010-03-20', 'city': 'Ahmedabad', 'venue': 'Narendra Modi Stadium', 'team1': 'Rajasthan Royals', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Rajasthan Royals', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'FY Fazal', 'non_striker': 'NV Ojha', 'bowler': 'SE Bond', 'overs': 4, 'balls': 4, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 42, 'wickets': 1, 'runs_last_5_overs': 42, 'wickets_last_5_overs': 1, 'target_overs': None, 'target_runs': None, 'balls_remaining': 92, 'runs_scored_in_remaining_balls': 126, 'runs_required': 0, 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 34.0, 'player_of_match': 'AA Jhunjhunwala', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'MJ Lumb, NV Ojha, FY Fazal, AA Jhunjhunwala, YK Pathan, AC Voges, P Dogra, SK Warne, MM Patel, SK Trivedi, SW Tait, MK Tiwary, BJ Hodge, CA Pujara, SC Ganguly, OA Shah, AD Mathews, WP Saha, M Kartik, AB Dinda, SE Bond, I Sharma', 'umpire1': 'RE Koertzen', 'umpire2': 'RB Tiffin', 'final_score': 168.0, 'total_wickets': 7}, {'match_id': 419118, 'year': 2010, 'date': '2010-03-20', 'city': 'Ahmedabad', 'venue': 'Narendra Modi Stadium', 'team1': 'Rajasthan Royals', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Rajasthan Royals', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'FY Fazal', 'non_striker': 'NV Ojha', 'bowler': 'SE Bond', 'overs': 4, 'balls': 5, 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 42, 'wickets': 1, 'runs_last_5_overs': 42, 'wickets_last_5_overs': 1, 'target_overs': None, 'target_runs': None, 'balls_remaining': 91, 'runs_scored_in_remaining_balls': 126, 'runs_required': 0, 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 34.0, 'player_of_match': 'AA Jhunjhunwala', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'MJ Lumb, NV Ojha, FY Fazal, AA Jhunjhunwala, YK Pathan, AC Voges, P Dogra, SK Warne, MM Patel, SK Trivedi, SW Tait, MK Tiwary, BJ Hodge, CA Pujara, SC Ganguly, OA Shah, AD Mathews, WP Saha, M Kartik, AB Dinda, SE Bond, I Sharma', 'umpire1': 'RE Koertzen', 'umpire2': 'RB Tiffin', 'final_score': 168.0, 'total_wickets': 7}, {'match_id': 419118, 'year': 2010, 'date': '2010-03-20', 'city': 'Ahmedabad', 'venue': 'Narendra Modi Stadium', 'team1': 'Rajasthan Royals', 'team2': 'Kolkata Knight Riders', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'bat', 'innings': 1, 'batting_team': 'Rajasthan Royals', 'bowling_team': 'Kolkata Knight Riders', 'batsman': 'FY Fazal', 'non_striker': 'NV Ojha', 'bowler': 'SE Bond', 'overs': 5, 'balls': 0, 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 1, 'dismissal_kind': 'caught', 'player_dismissed': 'FY Fazal', 'fielder': 'CA Pujara', 'extras_type': None, 'runs': 42, 'wickets': 2, 'runs_last_5_overs': 42, 'wickets_last_5_overs': 2, 'target_overs': None, 'target_runs': None, 'balls_remaining': 90, 'runs_scored_in_remaining_balls': 126, 'runs_required': 0, 'winner': 'Rajasthan Royals', 'result': 'runs', 'result_margin': 34.0, 'player_of_match': 'AA Jhunjhunwala', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'MJ Lumb, NV Ojha, FY Fazal, AA Jhunjhunwala, YK Pathan, AC Voges, P Dogra, SK Warne, MM Patel, SK Trivedi, SW Tait, MK Tiwary, BJ Hodge, CA Pujara, SC Ganguly, OA Shah, AD Mathews, WP Saha, M Kartik, AB Dinda, SE Bond, I Sharma', 'umpire1': 'RE Koertzen', 'umpire2': 'RB Tiffin', 'final_score': 168.0, 'total_w ...
# 2022-04-01 10:39:08,027 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:39:08,027 INFO sqlalchemy.engine.Engine [cached since 13.77s ago] ({'match_id': 419138, 'year': 2010, 'date': '2010-03-04', 'city': 'Mumbai', 'venue': 'Brabourne Stadium', 'team1': 'Mumbai Indians', 'team2': 'Deccan Chargers', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'bat', 'innings': 2, 'batting_team': 'Deccan Chargers', 'bowling_team': 'Mumbai Indians', 'batsman': 'HH Gibbs', 'non_striker': 'AC Gilchrist', 'bowler': 'Harbhajan Singh', 'overs': 2, 'balls': 2, 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 14, 'wickets': 0, 'runs_last_5_overs': 14, 'wickets_last_5_overs': 0, 'target_overs': 20.0, 'target_runs': 179.0, 'balls_remaining': 106, 'runs_scored_in_remaining_balls': 0, 'runs_required': 165, 'winner': 'Mumbai Indians', 'result': 'runs', 'result_margin': 63.0, 'player_of_match': 'AT Rayudu', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'S Dhawan, SR Tendulkar, SS Tiwary, DJ Bravo, AT Rayudu, KA Pollard, R Sathish, R McLaren, Harbhajan Singh, Z Khan, SL Malinga, HH Gibbs, AC Gilchrist, VVS Laxman, A Symonds, RG Sharma, MD Mishra, TL Suman, RJ Harris, R Sharma, Jaskaran Singh, PP Ojha', 'umpire1': 'BR Doctrove', 'umpire2': 'S Ravi', 'final_score': 115.0, 'total_wickets': 10}, {'match_id': 419138, 'year': 2010, 'date': '2010-03-04', 'city': 'Mumbai', 'venue': 'Brabourne Stadium', 'team1': 'Mumbai Indians', 'team2': 'Deccan Chargers', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'bat', 'innings': 2, 'batting_team': 'Deccan Chargers', 'bowling_team': 'Mumbai Indians', 'batsman': 'HH Gibbs', 'non_striker': 'AC Gilchrist', 'bowler': 'Harbhajan Singh', 'overs': 2, 'balls': 3, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 15, 'wickets': 0, 'runs_last_5_overs': 15, 'wickets_last_5_overs': 0, 'target_overs': 20.0, 'target_runs': 179.0, 'balls_remaining': 105, 'runs_scored_in_remaining_balls': 0, 'runs_required': 164, 'winner': 'Mumbai Indians', 'result': 'runs', 'result_margin': 63.0, 'player_of_match': 'AT Rayudu', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'S Dhawan, SR Tendulkar, SS Tiwary, DJ Bravo, AT Rayudu, KA Pollard, R Sathish, R McLaren, Harbhajan Singh, Z Khan, SL Malinga, HH Gibbs, AC Gilchrist, VVS Laxman, A Symonds, RG Sharma, MD Mishra, TL Suman, RJ Harris, R Sharma, Jaskaran Singh, PP Ojha', 'umpire1': 'BR Doctrove', 'umpire2': 'S Ravi', 'final_score': 115.0, 'total_wickets': 10}, {'match_id': 419138, 'year': 2010, 'date': '2010-03-04', 'city': 'Mumbai', 'venue': 'Brabourne Stadium', 'team1': 'Mumbai Indians', 'team2': 'Deccan Chargers', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'bat', 'innings': 2, 'batting_team': 'Deccan Chargers', 'bowling_team': 'Mumbai Indians', 'batsman': 'AC Gilchrist', 'non_striker': 'HH Gibbs', 'bowler': 'Harbhajan Singh', 'overs': 2, 'balls': 4, 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 17, 'wickets': 0, 'runs_last_5_overs': 17, 'wickets_last_5_overs': 0, 'target_overs': 20.0, 'target_runs': 179.0, 'balls_remaining': 104, 'runs_scored_in_remaining_balls': 0, 'runs_required': 162, 'winner': 'Mumbai Indians', 'result': 'runs', 'result_margin': 63.0, 'player_of_match': 'AT Rayudu', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'S Dhawan, SR Tendulkar, SS Tiwary, DJ Bravo, AT Rayudu, KA Pollard, R Sathish, R McLaren, Harbhajan Singh, Z Khan, SL Malinga, HH Gibbs, AC Gilchrist, VVS Laxman, A Symonds, RG Sharma, MD Mishra, TL Suman, RJ Harris, R Sharma, Jaskaran Singh, PP Ojha', 'umpire1': 'BR Doctrove', 'umpire2': 'S Ravi', 'final_score': 115.0, 'total_wickets':  ...
# 2022-04-01 10:39:10,408 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# ...
# 2022-04-01 10:40:43,595 INFO sqlalchemy.engine.Engine [cached since 109.3s ago] ({'match_id': 1254064, 'year': 2021, 'date': '2021-04-15', 'city': 'Mumbai', 'venue': 'Wankhede Stadium', 'team1': 'Delhi Capitals', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Delhi Capitals', 'bowling_team': 'Rajasthan Royals', 'batsman': 'Lalit Yadav', 'non_striker': 'RR Pant', 'bowler': 'CH Morris', 'overs': 7, 'balls': 2, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 42, 'wickets': 4, 'runs_last_5_overs': 31, 'wickets_last_5_overs': 3, 'target_overs': None, 'target_runs': None, 'balls_remaining': 76, 'runs_scored_in_remaining_balls': 105, 'runs_required': 0, 'winner': 'Rajasthan Royals', 'result': 'wickets', 'result_margin': 3.0, 'player_of_match': 'JD Unadkat', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PP Shaw, S Dhawan, AM Rahane, RR Pant, MP Stoinis, Lalit Yadav, TK Curran, CR Woakes, R Ashwin, K Rabada, Avesh Khan, JC Buttler, M Vohra, SV Samson, S Dube, DA Miller, R Parag, R Tewatia, CH Morris, JD Unadkat, C Sakariya, Mustafizur Rahman', 'umpire1': 'S Ravi', 'umpire2': 'VK Sharma', 'final_score': 147.0, 'total_wickets': 8}, {'match_id': 1254064, 'year': 2021, 'date': '2021-04-15', 'city': 'Mumbai', 'venue': 'Wankhede Stadium', 'team1': 'Delhi Capitals', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Delhi Capitals', 'bowling_team': 'Rajasthan Royals', 'batsman': 'Lalit Yadav', 'non_striker': 'RR Pant', 'bowler': 'CH Morris', 'overs': 7, 'balls': 3, 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 42, 'wickets': 4, 'runs_last_5_overs': 30, 'wickets_last_5_overs': 3, 'target_overs': None, 'target_runs': None, 'balls_remaining': 75, 'runs_scored_in_remaining_balls': 105, 'runs_required': 0, 'winner': 'Rajasthan Royals', 'result': 'wickets', 'result_margin': 3.0, 'player_of_match': 'JD Unadkat', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PP Shaw, S Dhawan, AM Rahane, RR Pant, MP Stoinis, Lalit Yadav, TK Curran, CR Woakes, R Ashwin, K Rabada, Avesh Khan, JC Buttler, M Vohra, SV Samson, S Dube, DA Miller, R Parag, R Tewatia, CH Morris, JD Unadkat, C Sakariya, Mustafizur Rahman', 'umpire1': 'S Ravi', 'umpire2': 'VK Sharma', 'final_score': 147.0, 'total_wickets': 8}, {'match_id': 1254064, 'year': 2021, 'date': '2021-04-15', 'city': 'Mumbai', 'venue': 'Wankhede Stadium', 'team1': 'Delhi Capitals', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Delhi Capitals', 'bowling_team': 'Rajasthan Royals', 'batsman': 'Lalit Yadav', 'non_striker': 'RR Pant', 'bowler': 'CH Morris', 'overs': 7, 'balls': 4, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 46, 'wickets': 4, 'runs_last_5_overs': 34, 'wickets_last_5_overs': 3, 'target_overs': None, 'target_runs': None, 'balls_remaining': 74, 'runs_scored_in_remaining_balls': 101, 'runs_required': 0, 'winner': 'Rajasthan Royals', 'result': 'wickets', 'result_margin': 3.0, 'player_of_match': 'JD Unadkat', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'PP Shaw, S Dhawan, AM Rahane, RR Pant, MP Stoinis, Lalit Yadav, TK Curran, CR Woakes, R Ashwin, K Rabada, Avesh Khan, JC Buttler, M Vohra, SV Samson, S Dube, DA Miller, R Parag, R Tewatia, CH Morris, JD Unadkat, C Sakariya, Mustafizur Rahman', 'umpire1': 'S Ravi', 'umpire2': 'VK Sharma', 'final_score': 147.0, 'total_wickets': 8}, {'match_id': 1254064, 'year' ...
# 2022-04-01 10:40:46,612 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:40:46,612 INFO sqlalchemy.engine.Engine [cached since 112.4s ago] ({'match_id': 1254084, 'year': 2021, 'date': '2021-01-05', 'city': 'Delhi', 'venue': 'Arun Jaitley Stadium', 'team1': 'Chennai Super Kings', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'innings': 2, 'batting_team': 'Mumbai Indians', 'bowling_team': 'Chennai Super Kings', 'batsman': 'KA Pollard', 'non_striker': 'HH Pandya', 'bowler': 'SN Thakur', 'overs': 17, 'balls': 3, 'batsman_runs': 4.0, 'extra_runs': 0.0, 'total_runs': 4.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 183, 'wickets': 4, 'runs_last_5_overs': 68, 'wickets_last_5_overs': 1, 'target_overs': 20.0, 'target_runs': 219.0, 'balls_remaining': 15, 'runs_scored_in_remaining_balls': 0, 'runs_required': 36, 'winner': 'Mumbai Indians', 'result': 'wickets', 'result_margin': 4.0, 'player_of_match': 'KA Pollard', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'RD Gaikwad, F du Plessis, MM Ali, SK Raina, AT Rayudu, RA Jadeja, MS Dhoni, SM Curran, SN Thakur, DL Chahar, L Ngidi, Q de Kock, RG Sharma, SA Yadav, KH Pandya, KA Pollard, HH Pandya, JDS Neesham, DS Kulkarni, RD Chahar, JJ Bumrah, TA Boult', 'umpire1': 'KN Ananthapadmanabhan', 'umpire2': 'CK Nandan', 'final_score': 219.0, 'total_wickets': 6}, {'match_id': 1254084, 'year': 2021, 'date': '2021-01-05', 'city': 'Delhi', 'venue': 'Arun Jaitley Stadium', 'team1': 'Chennai Super Kings', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'innings': 2, 'batting_team': 'Mumbai Indians', 'bowling_team': 'Chennai Super Kings', 'batsman': 'KA Pollard', 'non_striker': 'HH Pandya', 'bowler': 'SN Thakur', 'overs': 17, 'balls': 4, 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 185, 'wickets': 4, 'runs_last_5_overs': 69, 'wickets_last_5_overs': 1, 'target_overs': 20.0, 'target_runs': 219.0, 'balls_remaining': 14, 'runs_scored_in_remaining_balls': 0, 'runs_required': 34, 'winner': 'Mumbai Indians', 'result': 'wickets', 'result_margin': 4.0, 'player_of_match': 'KA Pollard', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'RD Gaikwad, F du Plessis, MM Ali, SK Raina, AT Rayudu, RA Jadeja, MS Dhoni, SM Curran, SN Thakur, DL Chahar, L Ngidi, Q de Kock, RG Sharma, SA Yadav, KH Pandya, KA Pollard, HH Pandya, JDS Neesham, DS Kulkarni, RD Chahar, JJ Bumrah, TA Boult', 'umpire1': 'KN Ananthapadmanabhan', 'umpire2': 'CK Nandan', 'final_score': 219.0, 'total_wickets': 6}, {'match_id': 1254084, 'year': 2021, 'date': '2021-01-05', 'city': 'Delhi', 'venue': 'Arun Jaitley Stadium', 'team1': 'Chennai Super Kings', 'team2': 'Mumbai Indians', 'toss_winner': 'Mumbai Indians', 'toss_decision': 'field', 'innings': 2, 'batting_team': 'Mumbai Indians', 'bowling_team': 'Chennai Super Kings', 'batsman': 'KA Pollard', 'non_striker': 'HH Pandya', 'bowler': 'SN Thakur', 'overs': 17, 'balls': 5, 'batsman_runs': 2.0, 'extra_runs': 0.0, 'total_runs': 2.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 187, 'wickets': 4, 'runs_last_5_overs': 70, 'wickets_last_5_overs': 1, 'target_overs': 20.0, 'target_runs': 219.0, 'balls_remaining': 13, 'runs_scored_in_remaining_balls': 0, 'runs_required': 32, 'winner': 'Mumbai Indians', 'result': 'wickets', 'result_margin': 4.0, 'player_of_match': 'KA Pollard', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'RD Gaikwad, F du Plessis, MM Ali, SK Raina, AT Rayudu, RA Jadeja, MS Dhoni, SM Curran, SN Thakur, DL Chahar, L Ngidi, Q de Kock, RG Sharma, SA Yadav, KH Pandya, KA Pollard, HH Pandya, JDS Neesham, DS Kulkarni, RD Chahar, JJ Bumrah, TA Boult', 'umpire1': 'KN Ananthapadmanabhan', 'umpire2': 'CK Nandan', 'fina ...
# 2022-04-01 10:40:49,493 INFO sqlalchemy.engine.Engine INSERT INTO match_details (match_id, year, date, city, venue, team1, team2, toss_winner, toss_decision, innings, batting_team, bowling_team, batsman, non_striker, bowler, overs, balls, batsman_runs, extra_runs, total_runs, non_boundary, is_wicket, dismissal_kind, player_dismissed, fielder, extras_type, runs, wickets, runs_last_5_overs, wickets_last_5_overs, target_overs, target_runs, balls_remaining, runs_scored_in_remaining_balls, runs_required, winner, result, result_margin, player_of_match, playoff, knockout, final, method, players, umpire1, umpire2, final_score, total_wickets) VALUES (%(match_id)s, %(year)s, %(date)s, %(city)s, %(venue)s, %(team1)s, %(team2)s, %(toss_winner)s, %(toss_decision)s, %(innings)s, %(batting_team)s, %(bowling_team)s, %(batsman)s, %(non_striker)s, %(bowler)s, %(overs)s, %(balls)s, %(batsman_runs)s, %(extra_runs)s, %(total_runs)s, %(non_boundary)s, %(is_wicket)s, %(dismissal_kind)s, %(player_dismissed)s, %(fielder)s, %(extras_type)s, %(runs)s, %(wickets)s, %(runs_last_5_overs)s, %(wickets_last_5_overs)s, %(target_overs)s, %(target_runs)s, %(balls_remaining)s, %(runs_scored_in_remaining_balls)s, %(runs_required)s, %(winner)s, %(result)s, %(result_margin)s, %(player_of_match)s, %(playoff)s, %(knockout)s, %(final)s, %(method)s, %(players)s, %(umpire1)s, %(umpire2)s, %(final_score)s, %(total_wickets)s)
# 2022-04-01 10:40:49,493 INFO sqlalchemy.engine.Engine [cached since 115.2s ago] ({'match_id': 1254106, 'year': 2021, 'date': '2021-07-10', 'city': 'Sharjah', 'venue': 'Sharjah Cricket Stadium', 'team1': 'Kolkata Knight Riders', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Rajasthan Royals', 'batsman': 'VR Iyer', 'non_striker': 'Shubman Gill', 'bowler': 'Mustafizur Rahman', 'overs': 7, 'balls': 5, 'batsman_runs': 0.0, 'extra_runs': 0.0, 'total_runs': 0.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 49, 'wickets': 0, 'runs_last_5_overs': 32, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 73, 'runs_scored_in_remaining_balls': 122, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 86.0, 'player_of_match': 'Shivam Mavi', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'Shubman Gill, VR Iyer, N Rana, RA Tripathi, KD Karthik, EJG Morgan, Shakib Al Hasan, SP Narine, LH Ferguson, CV Varun, Shivam Mavi, YBK Jaiswal, LS Livingstone, SV Samson, S Dube, Anuj Rawat, GD Phillips, R Tewatia, CH Morris, JD Unadkat, C Sakariya, Mustafizur Rahman', 'umpire1': 'MA Gough', 'umpire2': 'HAS Khalid', 'final_score': 171.0, 'total_wickets': 4}, {'match_id': 1254106, 'year': 2021, 'date': '2021-07-10', 'city': 'Sharjah', 'venue': 'Sharjah Cricket Stadium', 'team1': 'Kolkata Knight Riders', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Rajasthan Royals', 'batsman': 'VR Iyer', 'non_striker': 'Shubman Gill', 'bowler': 'Mustafizur Rahman', 'overs': 8, 'balls': 0, 'batsman_runs': 0.0, 'extra_runs': 1.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': 'legbyes', 'runs': 50, 'wickets': 0, 'runs_last_5_overs': 33, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 72, 'runs_scored_in_remaining_balls': 121, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 86.0, 'player_of_match': 'Shivam Mavi', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'Shubman Gill, VR Iyer, N Rana, RA Tripathi, KD Karthik, EJG Morgan, Shakib Al Hasan, SP Narine, LH Ferguson, CV Varun, Shivam Mavi, YBK Jaiswal, LS Livingstone, SV Samson, S Dube, Anuj Rawat, GD Phillips, R Tewatia, CH Morris, JD Unadkat, C Sakariya, Mustafizur Rahman', 'umpire1': 'MA Gough', 'umpire2': 'HAS Khalid', 'final_score': 171.0, 'total_wickets': 4}, {'match_id': 1254106, 'year': 2021, 'date': '2021-07-10', 'city': 'Sharjah', 'venue': 'Sharjah Cricket Stadium', 'team1': 'Kolkata Knight Riders', 'team2': 'Rajasthan Royals', 'toss_winner': 'Rajasthan Royals', 'toss_decision': 'field', 'innings': 1, 'batting_team': 'Kolkata Knight Riders', 'bowling_team': 'Rajasthan Royals', 'batsman': 'VR Iyer', 'non_striker': 'Shubman Gill', 'bowler': 'S Dube', 'overs': 8, 'balls': 1, 'batsman_runs': 1.0, 'extra_runs': 0.0, 'total_runs': 1.0, 'non_boundary': 0, 'is_wicket': 0, 'dismissal_kind': None, 'player_dismissed': None, 'fielder': None, 'extras_type': None, 'runs': 51, 'wickets': 0, 'runs_last_5_overs': 34, 'wickets_last_5_overs': 0, 'target_overs': None, 'target_runs': None, 'balls_remaining': 71, 'runs_scored_in_remaining_balls': 120, 'runs_required': 0, 'winner': 'Kolkata Knight Riders', 'result': 'runs', 'result_margin': 86.0, 'player_of_match': 'Shivam Mavi', 'playoff': 0, 'knockout': 0, 'final': 0, 'method': None, 'players': 'Shubman Gill, VR Iyer, N Rana, RA Tripathi, KD Karthik, EJG Morgan, Shakib Al Hasan, SP Narine, LH Ferguson, CV Varun, Shivam Mavi, YBK Jaiswal, LS Livingstone, SV Samson, S Dube, Anuj Rawat, GD Philli ...
# 2022-04-01 10:40:51,083 INFO sqlalchemy.engine.Engine COMMIT

# %%
# live_data_1 = pd.DataFrame(columns = ['batting_team_Chennai_Super_Kings', 'batting_team_Deccan_Chargers',
#        'batting_team_Delhi_Capitals', 'batting_team_Gujarat_Lions',
#        'batting_team_Kochi_Tuskers_Kerala',
#        'batting_team_Kolkata_Knight_Riders', 'batting_team_Mumbai_Indians',
#        'batting_team_Pune_Warriors', 'batting_team_Punjab_Kings',
#        'batting_team_Rajasthan_Royals', 'batting_team_Rising_Pune_Supergiant',
#        'batting_team_Royal_Challengers_Bangalore',
#        'batting_team_Sunrisers_Hyderabad', 'bowling_team_Chennai_Super_Kings',
#        'bowling_team_Deccan_Chargers', 'bowling_team_Delhi_Capitals',
#        'bowling_team_Gujarat_Lions', 'bowling_team_Kochi_Tuskers_Kerala',
#        'bowling_team_Kolkata_Knight_Riders', 'bowling_team_Mumbai_Indians',
#        'bowling_team_Pune_Warriors', 'bowling_team_Punjab_Kings',
#        'bowling_team_Rajasthan_Royals', 'bowling_team_Rising_Pune_Supergiant',
#        'bowling_team_Royal_Challengers_Bangalore',
#        'bowling_team_Sunrisers_Hyderabad', 'toss_decision_bat',
#        'toss_decision_field', 'venue_Arun_Jaitley_Stadium',
#        'venue_Barabati_Stadium', 'venue_Brabourne_Stadium',
#        'venue_Buffalo_Park', 'venue_De_Beers_Diamond_Oval',
#        'venue_Dr_DY_Patil_Sports_Academy',
#        'venue_Dr_YS_Rajasekhara_Reddy_ACA_VDCA_Cricket_Stadium',
#        'venue_Dubai_International_Cricket_Stadium', 'venue_Eden_Gardens',
#        'venue_Green_Park',
#        'venue_Himachal_Pradesh_Cricket_Association_Stadium',
#        'venue_Holkar_Cricket_Stadium',
#        'venue_JSCA_International_Stadium_Complex', 'venue_Kingsmead',
#        'venue_M_Chinnaswamy_Stadium', 'venue_MA_Chidambaram_Stadium',
#        'venue_Maharashtra_Cricket_Association_Stadium',
#        'venue_Narendra_Modi_Stadium', 'venue_Nehru_Stadium',
#        'venue_New_Wanderers_Stadium', 'venue_Newlands',
#        'venue_OUTsurance_Oval',
#        'venue_Punjab_Cricket_Association_IS_Bindra_Stadium',
#        'venue_Rajiv_Gandhi_International_Stadium',
#        'venue_Saurashtra_Cricket_Association_Stadium',
#        'venue_Sawai_Mansingh_Stadium',
#        'venue_Shaheed_Veer_Narayan_Singh_International_Stadium',
#        'venue_Sharjah_Cricket_Stadium', 'venue_Sheikh_Zayed_Stadium',
#        'venue_St_George\'s_Park', 'venue_SuperSport_Park',
#        'venue_Vidarbha_Cricket_Association_Stadium', 'venue_Wankhede_Stadium',
#        'overs', 'balls', 'runs', 'wickets', 'runs_last_5_overs',
#        'wickets_last_5_overs', 'balls_remaining', 'playoff', 'knockout',
#        'final'])

# %%
# live_data_2 = pd.DataFrame(columns = ['batting_team_Chennai_Super_Kings', 'batting_team_Deccan_Chargers',
#        'batting_team_Delhi_Capitals', 'batting_team_Gujarat_Lions',
#        'batting_team_Kochi_Tuskers_Kerala',
#        'batting_team_Kolkata_Knight_Riders', 'batting_team_Mumbai_Indians',
#        'batting_team_Pune_Warriors', 'batting_team_Punjab_Kings',
#        'batting_team_Rajasthan_Royals', 'batting_team_Rising_Pune_Supergiant',
#        'batting_team_Royal_Challengers_Bangalore',
#        'batting_team_Sunrisers_Hyderabad', 'bowling_team_Chennai_Super_Kings',
#        'bowling_team_Deccan_Chargers', 'bowling_team_Delhi_Capitals',
#        'bowling_team_Gujarat_Lions', 'bowling_team_Kochi_Tuskers_Kerala',
#        'bowling_team_Kolkata_Knight_Riders', 'bowling_team_Mumbai_Indians',
#        'bowling_team_Pune_Warriors', 'bowling_team_Punjab_Kings',
#        'bowling_team_Rajasthan_Royals', 'bowling_team_Rising_Pune_Supergiant',
#        'bowling_team_Royal_Challengers_Bangalore',
#        'bowling_team_Sunrisers_Hyderabad', 'toss_decision_bat',
#        'toss_decision_field', 'venue_Arun_Jaitley_Stadium',
#        'venue_Barabati_Stadium', 'venue_Brabourne_Stadium',
#        'venue_Buffalo_Park', 'venue_De_Beers_Diamond_Oval',
#        'venue_Dr_DY_Patil_Sports_Academy',
#        'venue_Dr_YS_Rajasekhara_Reddy_ACA_VDCA_Cricket_Stadium',
#        'venue_Dubai_International_Cricket_Stadium', 'venue_Eden_Gardens',
#        'venue_Green_Park',
#        'venue_Himachal_Pradesh_Cricket_Association_Stadium',
#        'venue_Holkar_Cricket_Stadium',
#        'venue_JSCA_International_Stadium_Complex', 'venue_Kingsmead',
#        'venue_M_Chinnaswamy_Stadium', 'venue_MA_Chidambaram_Stadium',
#        'venue_Maharashtra_Cricket_Association_Stadium',
#        'venue_Narendra_Modi_Stadium', 'venue_Nehru_Stadium',
#        'venue_New_Wanderers_Stadium', 'venue_Newlands',
#        'venue_OUTsurance_Oval',
#        'venue_Punjab_Cricket_Association_IS_Bindra_Stadium',
#        'venue_Rajiv_Gandhi_International_Stadium',
#        'venue_Saurashtra_Cricket_Association_Stadium',
#        'venue_Sawai_Mansingh_Stadium',
#        'venue_Shaheed_Veer_Narayan_Singh_International_Stadium',
#        'venue_Sharjah_Cricket_Stadium', 'venue_Sheikh_Zayed_Stadium',
#        'venue_St_George\'s_Park', 'venue_SuperSport_Park',
#        'venue_Vidarbha_Cricket_Association_Stadium', 'venue_Wankhede_Stadium',
#        'overs', 'balls', 'runs', 'wickets', 'runs_last_5_overs',
#        'wickets_last_5_overs', 'target_overs', 'target_runs',
#        'balls_remaining', 'runs_required', 'playoff', 'knockout', 'final'])
